# %% [markdown]
# # Python variables; Python numeric types (int float complex); Boolean values; type conversion; arithmetic operators; comparison operators; string datatype; string indexing; slicing; string formatting; string methods

# %%
print("Welcome to the world of Data and AI")
# Out:
# Welcome to the world of Data and AI

# %%
print(5)
# Out:
# 5

# %%
age = 27
print(age)
# Out:
# 27

# %%
name = "Anand Prakash"
salary = 1000000
city = "Sydney"
print(name)
print(salary)
print(city)
# Out:
# Anand Prakash
# 1000000
# Sydney

# %%
# Numeric Data Types
x = 10
y = 10.56
z = 10 + 11j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
# String Data type
x = "Machine Learning"
print(type(x))
# Out:
# <class 'str'>

# %%
# Boolean
is_student = True
is_loggedin = False
print(is_student)
print(is_loggedin)
print(type(is_student))
print(type(is_loggedin))
# Out:
# True
# False
# <class 'bool'>
# <class 'bool'>

# %%
print(5>3)
# Out:
# True

# %%
age = "25"
print(type(age))
age = (int(age))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
y = 10
print(type(y))
y = float(y)
print(type(y))
# Out:
# <class 'int'>
# <class 'float'>

# %%
num = 50
print(type(num))
num = str(num)
print(type(num))
# Out:
# <class 'int'>
# <class 'str'>

# %%
print(bool(0))
print(bool(1))
print(bool(""))
print(bool("AI"))
# Out:
# False
# True
# False
# True

# %%
actual = 80
predicted = 70
error = actual - predicted
squared_error = error ** 2
print(squared_error)
# Out:
# 100

# %%
text = "Python"
print(text[0])
print(text[-1])
# Out:
# P
# n

# %%
text = "Artificial"
print(text[0:4])
print(text[:4])
print(text[4:-1])
print(text[:-1])
print(text[4:])
# Out:
# Arti
# Arti
# ficia
# Artificia
# ficial

# %%
word = "machinelearning"
print(word[0:15:2])
# Out:
# mcieerig

# %%
name = "Tommy"
salary = 50000
print("Hello " + name + " your salary " + str(salary))
# Out:
# Hello Tommy your salary 50000

# %%
print(f"Hello {name} your salary is {salary}")
# Out:
# Hello Tommy your salary is 50000

# %%
text = "PyThon"
print((text).lower())
print((text).upper())
print((text).capitalize())
# Out:
# python
# PYTHON
# Python

# %%
text = "I love Java"
print(text.replace("", "Pizza"))
print(text.replace("Java","Pizza"))
print(text.split())
print(text.split("love"))
# Out:
# PizzaIPizza PizzalPizzaoPizzavPizzaePizza PizzaJPizzaaPizzavPizzaaPizza
# I love Pizza
# ['I', 'love', 'Java']
# ['I ', ' Java']

# %%
text = "  toomy"
print(text)
print(text.strip())
# Out:
#   toomy
# toomy
