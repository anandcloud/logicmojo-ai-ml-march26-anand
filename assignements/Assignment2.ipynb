# %% [markdown]
# ##REGEX

# %% [markdown]
# Q1. Division with Exception Handling
#
# Write a program that takes two numbers and safely performs division.
# Handle division by zero using try-except.

# %%
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
try:
    result = num1/num2
except ZeroDivisionError:
    result = "Cannot Divide by Zero"
print(result)
# Out:
# Enter the first number:  5
# Enter the second number:  0
# Cannot Divide by Zero

# %% [markdown]
# Q2. String to Integer Conversion
#
# Given a list:
#
# data = ["10", "20", "abc", "30"]
#
# Convert all values to integers.
# Skip invalid values using exception handling.

# %%
data = ["10", "20", "abc", "30"]
for i in range(len(data)):
    try:
        data[i] = int(data[i])
    except ValueError:
        print(f"Skipping the item {data[i]}")
print(data)
# Out:
# Skipping the item abc
# [10, 20, 'abc', 30]

# %% [markdown]
# Q3. Multiple Exception Handling
#
# Write a program that:
#
# Takes user input
# Converts it to integer
# Divides 100 by that number
#
# Handle:
#
# ValueError
# ZeroDivisionError

# %%
number = int(input("Enter the number: "))
try:
    result = 100/number
except ZeroDivisionError:
    result = "Cannot Divide by Zero"
print(result)
# Out:
# Enter the number:  5
# 20.0

# %% [markdown]
# Q4. Using finally
#
# Write a program that:
#
# Opens a file (dummy)
# Prints a message
# Ensures a “Closing file” message always runs using finally

# %%
try:
    file = open("dummy.txt","x")
    file.write("This is a dummy file")
except FileExistsError:
    print("The file already exist")
finally:
    file.close()
    print("File is closed")
# Out:
# File is closed

# %%
import os
file_path = "dummy.txt"
os.remove("dummy.txt")

# %% [markdown]
# Q5. Using assert
#
# Write a program that checks if a number is positive using assert.

# %%
num = 10
assert num > 0, "The number should be positive"

# %% [markdown]
# Q6. Clean Text
#
# Given:
#
# text = "   Hello Python   "
#
# Remove spaces and convert to lowercase.

# %%
text = " Hello Python "
newtext = text.strip().lower()
print(newtext)
# Out:
# hello python

# %% [markdown]
# Q7. Replace Words
#
# Replace all occurrences of "Python" with "AI" in:
#
# text = "Python is great. Python is easy."

# %%
text = "Python is great. Python is easy."
newtext = text.replace("Python", "AI")
print(newtext)
# Out:
# AI is great. AI is easy.

# %% [markdown]
# Q8. Split and Join
#
# Convert:
#
# text = "apple,banana,orange"
#
# Into:
#
# "apple banana orange"

# %%
text = "apple,banana,orange"
stext = text.split(",")
print(stext)
ntext = " ".join(stext)
print(ntext)
# Out:
# ['apple', 'banana', 'orange']
# apple banana orange

# %% [markdown]
# Q9. Count Words
#
# Count number of words in a sentence using split.

# %%
text = "Count number of words in a sentence using split."
stext = text.split(" ")
print(stext)
print(f"The number of words in sentense are {len(stext)}")
# Out:
# ['Count', 'number', 'of', 'words', 'in', 'a', 'sentence', 'using', 'split.']
# The number of words in sentense are 9

# %% [markdown]
# Q10. Reverse Words
#
# Reverse words in a string:
#
# "I love AI"

# %%
text = "I love AI"
stext = text.split()
print(stext)
revtext = stext[::-1]
print(revtext)
reverse_text = " ".join(revtext)
print(reverse_text)
# Out:
# ['I', 'love', 'AI']
# ['AI', 'love', 'I']
# AI love I

# %% [markdown]
# Q11. Find Digits
#
# Extract all digits from:
#
# text = "My number is 98765"

# %%
text = "My number is 98765"
import re
numb = re.findall("\d+", text)
print(numb)
# Out:
# ['98765']

# %% [markdown]
# Q12. Find Words Starting with 'a'
#
# From:
#
# text = "apple banana avocado berry"
#
# Extract words starting with 'a'.

# %%
text = "apple banana avocado berry"
import re
atext = re.findall(r"\ba\w+", text)
print(atext)
# Out:
# ['apple', 'avocado']

# %% [markdown]
# Q13. Extract Emails
#
# Extract emails from:
#
# text = "Contact: test@gmail.com, admin@yahoo.com"

# %%
text = "Contact: test@gmail.com, admin@yahoo.com"
import re
email = re.findall(r"\w+@\w+\.\w+", text)
print(email)
# Out:
# ['test@gmail.com', 'admin@yahoo.com']

# %% [markdown]
# Q14. Validate Phone Numbers
#
# Extract valid 10-digit phone numbers from:
#
# text = "Call 9876543210 or 12345"

# %%
text = "Call 9876543210 or 12345"
mobile = re.findall(r"\d{10}", text)
print(mobile)
# Out:
# ['9876543210']

# %% [markdown]
# Q15. Replace Digits
#
# Replace all digits with "X" in:
#
# text = "My number is 98765"

# %%
text = "My number is 98765"
new_text = re.sub(r"\d+", "*****", text)
print(new_text)
# Out:
# My number is *****

# %% [markdown]
# Q16. Extract Dates
#
# Extract date from:
#
# text = "Today is 2026-03-28"
#
# Return:
#
# Year
# Month
# Day

# %%
text = "Today is 2026-03-28"
new_text = re.findall(r"\d+", text)
date_text = " ".join(new_text)
print(date_text)
# Out:
# 2026 03 28

# %% [markdown]
# Q. 17 Extract numbers followed by "rs":
#
# text = "100rs 200usd 300rs"

# %%
text = "100rs 200usd 300rs"
num_rs = re.findall(r"(\d+)rs", text)
print(num_rs)
# Out:
# ['100', '300']

# %% [markdown]
# Q. 18 Extract numbers that come after "rs":
#
# text = "rs100 rs200 usd300"

# %%
text = "100rs 200usd 300rs"
num_rs = re.findall(r"(\d+)rs", text)
print(num_rs)
# Out:
# ['100', '300']

# %% [markdown]
# Q. 19 Extract Valid Transaction Records Using a Single Regex Pattern
#
# You are given a messy log string:
#
# log = """
# ID:TXN12345 | User: Mahipal_01 | Email: mahi123@gmail.com | Phone: +91-9876543210 | Amount: Rs.5000
# ID:TXN12 | User: @InvalidUser | Email: wronggmail.com | Phone: 98765 | Amount: Rs.-200
# ID:TXN99999 | User: Ravi_kumar | Email: ravi.kumar@yahoo.com | Phone: +91-9123456789 | Amount: USD300
# ID:TXN54321 | User: Sita99 | Email: sita99@gmail | Phone: +91-9999999999 | Amount: Rs.7000
#
#
# Write a single REGEX pattern that extracts ONLY VALID records where:
# CONDITIONS (VERY IMPORTANT)
# Transaction ID
# Format: TXN followed by exactly 5 digits
# Example: TXN12345
# Use: ^, {}, \d
#
# Username
# Only letters, numbers, underscore
# Must start with a letter
# Example: Mahipal_01
# Use: [a-zA-Z], \w, +
#
# Email
# Valid format: word@word.domain
# Example: test123@gmail.com
# Use: \w, ., @, +, \.
#
# Phone Number
# Format: +91-XXXXXXXXXX
# Exactly 10 digits
# Use: \+, \d, {}
#
# Amount
# Currency: Rs or USD
# Amount must be positive
# Example: Rs.5000, USD300
# Use: (rs|usd), \d+, ?
#
#
#
#
# EXPECTED OUTPUT
#
# Only valid records should match:
#
# [
# "ID:TXN12345 | User: Mahipal_01 | Email: mahi123@gmail.com | Phone: +91-9876543210 | Amount: Rs.5000",
#
# "ID:TXN99999 | User: Ravi_kumar | Email: ravi.kumar@yahoo.com | Phone: +91-9123456789 | Amount: USD300"
# ]

# %%
import re
log = """
ID:TXN12345 | User: Mahipal_01 | Email: mahi123@gmail.com | Phone: +91-9876543210 | Amount: Rs.5000
ID:TXN12 | User: @InvalidUser | Email: wronggmail.com | Phone: 98765 | Amount: Rs.-200
ID:TXN99999 | User: Ravi_kumar | Email: ravi.kumar@yahoo.com | Phone: +91-9123456789 | Amount: USD300
ID:TXN54321 | User: Sita99 | Email: sita99@gmail | Phone: +91-9999999999 | Amount: Rs.7000
"""
pattern = "^ID:TXN\d{5}\s*\|\s*User:\s*[a-zA-Z]\w+\s*\|\s*Email:\s*[\w.]+@\w+\.[a-zA-Z]{3}\s*\|\s*Phone:\s*\+91-\d{10}\s*\|\s*Amount:\s*(?:Rs\.\d+|USD\d+)$" 
new_log = re.findall(pattern, log, re.MULTILINE)
print(new_log)
# Out:
# ['ID:TXN12345 | User: Mahipal_01 | Email: mahi123@gmail.com | Phone: +91-9876543210 | Amount: Rs.5000', 'ID:TXN99999 | User: Ravi_kumar | Email: ravi.kumar@yahoo.com | Phone: +91-9123456789 | Amount: USD300']

# %% [markdown]
# **Assignment 2 Data Structures & Functions**

# %% [markdown]
# ## 1. Customer Segmentation Engine
#
# You are given a list of customer dictionaries:
#
# ```python
# customers = [
#     {"id": 1, "age": 25, "income": 50000, "spend": 20000},
#     {"id": 2, "age": 45, "income": 120000, "spend": 80000},
#     {"id": 3, "age": 35, "income": 70000, "spend": 30000}
# ]
# ```
#
# Task:
#
# 1. Write a function segment_customer(customer):
# 2. If spend divided by income is greater than 0.6 return "High Value"
# 3. If spend divided by income is between 0.3 and 0.6 return "Medium Value"
# 4. Otherwise return "Low Value"
# 5. Create a final dictionary in the format {customer_id: segment}

# %%
customers = [
    {"id": 1, "age": 25, "income": 50000, "spend": 20000},
    {"id": 2, "age": 45, "income": 120000, "spend": 80000},
    {"id": 3, "age": 35, "income": 70000, "spend": 30000}
]
def segment_customer(customer):
    val = cust["spend"] /cust["income"]
    if val > 0.6:
        return "High Value"
    elif val > 0.3 and val < 0.6:
        return "Medium Value"
    else:
        return "Low Value"    
customer_segment = {}
for cust in customers:
    segment = segment_customer(cust)
    customer_segment[cust["id"]] = segment
    print(f"Customer Id:{cust["id"]} aged {cust["age"]} is in Segement {segment}")
print(customer_segment)
# Out:
# Customer Id:1 aged 25 is in Segement Medium Value
# Customer Id:2 aged 45 is in Segement High Value
# Customer Id:3 aged 35 is in Segement Medium Value
# {1: 'Medium Value', 2: 'High Value', 3: 'Medium Value'}

# %% [markdown]
# ## 2. Text Cleaning Pipeline
#
# You are given:
#
# ```python
# texts = [
#     "Hello!!! How are you???",
#     "This is    AI     class.",
#     "Python@@@is###great"
# ]
# ```
#
# Task:
#
# 1. Write a function clean_text(text):
# 2. Remove special characters
# 3. Remove extra spaces
# 4. Convert text to lowercase
# 5. Apply the function to all elements using loop or map
# 6. Return cleaned list
#
# ---

# %%
texts = [
    "Hello!!! How are you???",
    "This is    AI     class.",
    "Python@@@is###great"
]
import re
def clean_text(text):
    new_text = re.sub("[^a-zA-Z0-9]", ' ',text)
    new_text = re.sub("\s+", ' ', new_text)
    new_text = new_text.lower()
    new_text = new_text.strip()
    return new_text
clean_list = []
for text in texts:
    cleant = clean_text(text)
    clean_list.append(cleant)
    print(cleant)
print(clean_list)
# Out:
# hello how are you
# this is ai class
# python is great
# ['hello how are you', 'this is ai class', 'python is great']

# %% [markdown]
# ## 3. Fraud Detection Rule Engine
#
# You are given:
#
# ```python
# transactions = [
#     {"id": 101, "amount": 5000, "location": "India"},
#     {"id": 102, "amount": 200000, "location": "Unknown"},
#     {"id": 103, "amount": 1000, "location": "India"}
# ]
# ```
#
# Task:
#
# 1. Write a function is_fraud(transaction)
# 2. If amount is greater than 100000 or location is "Unknown" mark as fraud
# 3. Otherwise mark as safe
# 4. Use lambda with filter or map
# 5. Return only fraud transactions

# %%
transactions = [
    {"id": 101, "amount": 5000, "location": "India"},
    {"id": 102, "amount": 200000, "location": "Unknown"},
    {"id": 103, "amount": 1000, "location": "India"}
]

def  is_fraud(transaction):
    return transaction["amount"] > 100000 or transaction["location"] == "Unknown"

result = filter(lambda tran:is_fraud(tran), transactions)
print(list(result))
# Out:
# [{'id': 102, 'amount': 200000, 'location': 'Unknown'}]

# %% [markdown]
# ## 4. Feature Engineering
#
# You are given:
#
# ```python
# data = [
#     {"salary": 50000, "experience": 2},
#     {"salary": 100000, "experience": 5}
# ]
# ```
#
# Task:
#
# 1. Write a function feature_engineer(record)
# 2. Add a new key salary_per_exp
# 3. salary_per_exp is salary divided by experience
# 4. Handle division by zero using conditional logic
# 5. Return updated dataset
#
# ---

# %%
data = [
    {"salary": 50000, "experience": 2},
    {"salary": 100000, "experience": 5},
    {"salary": 10000, "experience": 0}
]
def feature_engineer(record):
    try:
        record["salary_per_exp"] = record["salary"] /record["experience"]
        return record
    except ZeroDivisionError:
        record["salary_per_exp"] = "Zero Experience"
        return record
    
result = map(lambda record: feature_engineer(record), data)
print(list(result))
# Out:
# [{'salary': 50000, 'experience': 2, 'salary_per_exp': 25000.0}, {'salary': 100000, 'experience': 5, 'salary_per_exp': 20000.0}, {'salary': 10000, 'experience': 0, 'salary_per_exp': 'Zero Experience'}]

# %% [markdown]
# ## 5. Custom Reduce Function
#
# You are given:
#
# ```python
# accuracies = [0.8, 0.75, 0.9, 0.85]
# ```
#
# Task:
#
# 1. Use reduce function to calculate average accuracy
# 2. Do not use sum function
# 3. Show intermediate logic using a custom function

# %%
from functools import reduce
accuracies = [0.8, 0.75, 0.9, 0.85]
def custom_sum(accumulator, current_value):
    return accumulator + current_value

total_sum = reduce(custom_sum, accuracies)
average_accuracy = total_sum/len(accuracies)
print(average_accuracy)
# Out:
# 0.8250000000000001

# %% [markdown]
# ## 6. Sequence Pattern Detection
#
# You are given:
#
# ```python
# data = [10, 20, 30, 25, 40, 50]
# ```
#
# Task:
#
# 1. Write a function detect_increasing_sequence(data)
# 2. Find the longest continuous increasing sequence
# 3. Return that sequence as a list
#
# Example output:
#
# ```python
# [10, 20, 30]
# ```

# %%
data = [10, 20, 30, 25, 40, 50]
def detect_increasing_sequence(data):
    seq_data = []
    initial = 0
    for dat in data:
        if initial < dat:
            seq_data.append(dat)
            initial = dat
        else:
            break
    return seq_data
print(detect_increasing_sequence(data))
# Out:
# [10, 20, 30]

# %% [markdown]
# ## 7. Dictionary-Based Recommendation System
#
# You are given:
#
# ```python
# user_purchases = {
#     "user1": ["apple", "banana"],
#     "user2": ["banana", "orange"],
#     "user3": ["apple", "orange"]
# }
# ```
#
# Task:
#
# 1. Write a function recommend(user)
# 2. Recommend items based on common items between users
# 3. Do not recommend items already purchased by the user
# 4. Use sets and dictionary iteration
#
# ---

# %%
user_purchases = {
    "user1": ["apple", "banana"],
    "user2": ["banana", "orange"],
    "user3": ["apple", "orange"]
}
def recommend(user):
    fruits = {"apple", "banana", "orange"}
    remaining = fruits - set(user)
    return list(remaining)[0]
for user, bought_items in user_purchases.items():
    fruit = recommend(bought_items)
    print(f"The {user} recommended to buy {fruit}")
# Out:
# The user1 recommended to buy orange
# The user2 recommended to buy apple
# The user3 recommended to buy banana

# %% [markdown]
# ## 8. Recursive Decision Tree Simulation
#
# Task:
#
# 1. Write a recursive function decision_tree(score)
# 2. If score is greater than 80 return "Approved"
# 3. If score is between 50 and 80 call the function again with score plus 10
# 4. If score is less than 50 return "Rejected"
#
# ---
